# %%
import pandas as pd
import os

# %% [markdown]
# # VISUALIZING THE TABLES PRESENTED

# %%
# ZIPPED 1 
basis_results = '/Users/fallonhome/Desktop/DSC100 Project1/Data/120-years-of-olympic-history-athletes-and-results'
athlete_events = basis_results + '/athlete_events.csv'
noc_regions = basis_results + '/noc_regions.csv'

# ZIPPED 2
basis_games = '/Users/fallonhome/Desktop/DSC100 Project1/Data/olympic-games'
dictionary_data = basis_games + "/dictionary.csv"
summer_data = basis_games + "/summer.csv"
winter_data = basis_games + "/winter.csv"

# %%
# table declarations
athletes = pd.read_csv(athlete_events)
regions = pd.read_csv(noc_regions)
dictionary = pd.read_csv(dictionary_data)
summer = pd.read_csv(summer_data)
winter = pd.read_csv(winter_data)

# %%
# displaying tables
print('ATHLETE TABLES \b\b')
print("PK: ID")
print("FK: NOC")
print("CK: Name (composite?)")
display(athletes.head())
print('\b\bREGIONS TABLE  \b\b')
print("PK: NOC")
display(regions.head())
print('='*100)
print('\b\bDICTIONARY TABLE  \b\b')
print('PK: Code')
print('CK: Country')
display(dictionary.head())
print('\b\bSUMMMER TABLE  \b\b')
print('PK: Athlete (composite key)')
display(summer.head())
print('\b\bWINTER TABLE  \b\b')
print('PK: Athlete (composite key)')
display(winter.head())

print('\bNOTES \b')
print('Country column in [summer, winter] tables is a relationship ' +
      'for the Code column in [dictionary] table.'
     )
# Out:
# ATHLETE TABLES
# PK: ID
# FK: NOC
# CK: Name (composite?)
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# ...
